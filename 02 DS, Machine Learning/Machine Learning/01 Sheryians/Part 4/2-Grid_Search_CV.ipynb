# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import warnings 
warnings.filterwarnings('ignore')

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('species', axis=1) 
y = df['species']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model_KNN = KNeighborsClassifier(n_neighbors=13)

# %%
model_KNN.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=13)

# %%
model_KNN.score(X_test, y_test)
# Out:
# 1.0

# %%
from sklearn.svm import SVC

# %%
model_SVM = SVC(gamma='auto')

# %%
model_SVM.fit(X_train, y_train)
# Out:
# SVC(gamma='auto')

# %%
model_SVM.score(X_test, y_test)
# Out:
# 1.0

# %%
# Grid Search CV

# %%
from sklearn.model_selection import GridSearchCV

# %%
classifier = GridSearchCV((model_SVM), {
    'C': [1, 10, 20, 30],
    'kernel': ['rbf', 'linear']
}, cv=5, return_train_score= False)

# %%
classifier.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=SVC(gamma='auto'),
#              param_grid={'C': [1, 10, 20, 30], 'kernel': ['rbf', 'linear']})

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([0.00503607, 0.00344791, 0.00379906, 0.00319991, 0.00361595,
#         0.00340719, 0.00390134, 0.00367627]),
#  'std_fit_time': array([0.00087823, 0.00055434, 0.00039928, 0.00040014, 0.00082797,
#         0.00048969, 0.00049185, 0.00094262]),
#  'mean_score_time': array([0.00347347, 0.00262218, 0.00240617, 0.00279994, 0.00223131,
#         0.00252185, 0.0023005 , 0.00291514]),
#  'std_score_time': array([0.00107204, 0.00079998, 0.0004974 , 0.0003998 , 0.00038907,
#         0.00066717, 0.00040013, 0.00113566]),
#  'param_C': masked_array(data=[1, 1, 10, 10, 20, 20, 30, 30],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value=999999),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'rbf', 'linear', 'rbf', 'linear',
#                     'rbf', 'linear'],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
# ...

# %%
results = pd.DataFrame(classifier.cv_results_)

# %%
results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.005036      0.000878         0.003473        0.001072        1
# 1       0.003448      0.000554         0.002622        0.000800        1
# 2       0.003799      0.000399         0.002406        0.000497       10
# 3       0.003200      0.000400         0.002800        0.000400       10
# 4       0.003616      0.000828         0.002231        0.000389       20
# 5       0.003407      0.000490         0.002522        0.000667       20
# 6       0.003901      0.000492         0.002301        0.000400       30
# 7       0.003676      0.000943         0.002915        0.001136       30
#
#   param_kernel                         params  split0_test_score  \
# 0          rbf      {'C': 1, 'kernel': 'rbf'}           0.966667
# 1       linear   {'C': 1, 'kernel': 'linear'}           0.966667
# 2          rbf     {'C': 10, 'kernel': 'rbf'}           0.966667
# ...

# %%
results[['param_C', 'param_kernel', 'mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0        1          rbf         0.980000
# 1        1       linear         0.980000
# 2       10          rbf         0.980000
# 3       10       linear         0.973333
# 4       20          rbf         0.966667
# 5       20       linear         0.966667
# 6       30          rbf         0.960000
# 7       30       linear         0.960000

# %%
# KNN

# %%
classifier2 = GridSearchCV(model_KNN, {
    'n_neighbors': [3, 5, 7, 9, 11, 13],   # Try different neighbor values
    'weights': ['uniform', 'distance'],  # Optional: Add weight types
    'metric': ['euclidean', 'manhattan']  # Optional: Add distance metrics
}, cv=5, return_train_score=False)

# %%
classifier2.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(n_neighbors=13),
#              param_grid={'metric': ['euclidean', 'manhattan'],
#                          'n_neighbors': [3, 5, 7, 9, 11, 13],
#                          'weights': ['uniform', 'distance']})

# %%
classifier2.cv_results_
# Out:
# {'mean_fit_time': array([0.00400743, 0.00329533, 0.00291104, 0.00279989, 0.00308948,
#         0.00314689, 0.00378251, 0.00259933, 0.0027998 , 0.00279999,
#         0.00320005, 0.00259924, 0.00299973, 0.00300083, 0.00300016,
#         0.00319819, 0.0026    , 0.00361724, 0.0031579 , 0.00323186,
#         0.00352545, 0.00265465, 0.00302324, 0.00280557]),
#  'std_fit_time': array([6.56464412e-04, 5.62139857e-04, 1.80588336e-04, 4.00138082e-04,
#         1.76768712e-04, 8.63561664e-04, 9.62165381e-04, 4.89862952e-04,
#         3.99971293e-04, 4.00186732e-04, 4.00066461e-04, 4.89397747e-04,
#         5.91739352e-07, 6.32411770e-04, 2.10349512e-06, 4.00411590e-04,
#         4.90018415e-04, 5.05523235e-04, 3.17791715e-04, 7.82656966e-04,
#         5.08702194e-04, 5.41009731e-04, 6.34957452e-04, 4.02848349e-04]),
#  'mean_score_time': array([0.00865164, 0.00352755, 0.00624981, 0.00302591, 0.00621018,
#         0.00327024, 0.00752473, 0.00300045, 0.00619984, 0.00319982,
# ...

# %%
result = pd.DataFrame(classifier2.cv_results_)
result
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_metric  \
# 0        0.004007  6.564644e-04         0.008652    2.458683e-03    euclidean
# 1        0.003295  5.621399e-04         0.003528    4.587582e-04    euclidean
# 2        0.002911  1.805883e-04         0.006250    4.747823e-04    euclidean
# 3        0.002800  4.001381e-04         0.003026    5.178517e-05    euclidean
# 4        0.003089  1.767687e-04         0.006210    4.020888e-04    euclidean
# 5        0.003147  8.635617e-04         0.003270    5.474073e-04    euclidean
# 6        0.003783  9.621654e-04         0.007525    1.047377e-03    euclidean
# 7        0.002599  4.898630e-04         0.003000    7.136645e-07    euclidean
# 8        0.002800  3.999713e-04         0.006200    4.000670e-04    euclidean
# 9        0.002800  4.001867e-04         0.003200    3.999482e-04    euclidean
# 10       0.003200  4.000665e-04         0.006200    3.996850e-04    euclidean
# ...

# %%
result
