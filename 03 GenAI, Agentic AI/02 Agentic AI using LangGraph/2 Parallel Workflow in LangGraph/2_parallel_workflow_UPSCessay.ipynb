# %%
from langchain_openai import ChatOpenAI
from langgraph.graph import StateGraph, START, END
from typing import TypedDict, Annotated
from pydantic import BaseModel, Field
from dotenv import load_dotenv
import operator

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI(model='gpt-4o-mini')

# %%
# StrOutputModel
class EvaluationSchema(BaseModel):
    feedback: str = Field(description='Give me Detailed feedback on the essay')
    score: int = Field(description='Give me a score on a scale of 1-10', ge=0, le=10)

# %%
structured_model = model.with_structured_output(EvaluationSchema)

# %%
essay = """India in the Age of AI
As the world enters a transformative era defined by artificial intelligence (AI), India stands at a critical juncture — one where it can either emerge as a global leader in AI innovation or risk falling behind in the technology race. The age of AI brings with it immense promise as well as unprecedented challenges, and how India navigates this landscape will shape its socio-economic and geopolitical future.

India's strengths in the AI domain are rooted in its vast pool of skilled engineers, a thriving IT industry, and a growing startup ecosystem. With over 5 million STEM graduates annually and a burgeoning base of AI researchers, India possesses the intellectual capital required to build cutting-edge AI systems. Institutions like IITs, IIITs, and IISc have begun fostering AI research, while private players such as TCS, Infosys, and Wipro are integrating AI into their global services. In 2020, the government launched the National AI Strategy (AI for All) with a focus on inclusive growth, aiming to leverage AI in healthcare, agriculture, education, and smart mobility.

One of the most promising applications of AI in India lies in agriculture, where predictive analytics can guide farmers on optimal sowing times, weather forecasts, and pest control. In healthcare, AI-powered diagnostics can help address India’s doctor-patient ratio crisis, particularly in rural areas. Educational platforms are increasingly using AI to personalize learning paths, while smart governance tools are helping improve public service delivery and fraud detection.

However, the path to AI-led growth is riddled with challenges. Chief among them is the digital divide. While metropolitan cities may embrace AI-driven solutions, rural India continues to struggle with basic internet access and digital literacy. The risk of job displacement due to automation also looms large, especially for low-skilled workers. Without effective skilling and re-skilling programs, AI could exacerbate existing socio-economic inequalities.

Another pressing concern is data privacy and ethics. As AI systems rely heavily on vast datasets, ensuring that personal data is used transparently and responsibly becomes vital. India is still shaping its data protection laws, and in the absence of a strong regulatory framework, AI systems may risk misuse or bias.

To harness AI responsibly, India must adopt a multi-stakeholder approach involving the government, academia, industry, and civil society. Policies should promote open datasets, encourage responsible innovation, and ensure ethical AI practices. There is also a need for international collaboration, particularly with countries leading in AI research, to gain strategic advantage and ensure interoperability in global systems.

India’s demographic dividend, when paired with responsible AI adoption, can unlock massive economic growth, improve governance, and uplift marginalized communities. But this vision will only materialize if AI is seen not merely as a tool for automation, but as an enabler of human-centered development.

In conclusion, India in the age of AI is a story in the making — one of opportunity, responsibility, and transformation. The decisions we make today will not just determine India’s AI trajectory, but also its future as an inclusive, equitable, and innovation-driven society."""

# %%
prompt = f"Evaluate the language quality of the following essay and provide a feedback and assign a score out of 10 \n {essay}"

structured_model.invoke(prompt).score
# Out:
# 8

# %%
# State 
class UPSCState(TypedDict):
    essay: str
    language_feedback: str
    analysis_feedback: str
    clarity_feedback: str
    
    overall_feedback: str
    individual_scores: Annotated[list[int], operator.add]
    avg_score: float

# %%
#  funaction for Language_Evaluation
def language_evaluation(state: UPSCState) -> UPSCState:
    prompt = f"Evaluate the language quality of the following essay and provide a feedback and assign a score out of 10 \n {state['essay']}"
    output = structured_model.invoke(prompt)
    
    return {"language_feedback": output.feedback, "individual_scores": [output.score]}

# %%
# function for Analysis_Evaluation
def analysis_evaluation(state: UPSCState) -> UPSCState:
    prompt = f"Evaluate the analysis quality of the following essay and provide a feedback and assign a score out of 10 \n {state['essay']}"
    output = structured_model.invoke(prompt)
    
    return {"analysis_feedback": output.feedback, "individual_scores": [output.score]}

# %%
# Funaction for Clarity_Evaluation
def clarity_evaluation(state: UPSCState) -> UPSCState:
    prompt = f"Evaluate the clarity quality of the following essay and provide a feedback and assign a score out of 10 \n {state['essay']}"
    output = structured_model.invoke(prompt)
    
    return {"clarity_feedback": output.feedback, "individual_scores": [output.score]}

# %%
# Function for Final_Evaluation
def final_evaluation(state: UPSCState) -> UPSCState:
    # Summary Feedback
    prompt = f'Based on the following feedbacks create a summarized feedback \n language feedback - {state["language_feedback"]} \n depth of analysis feedback - {state["analysis_feedback"]} \n clarity of quality feedback - {state["clarity_feedback"]}'
    overall_feedback = model.invoke(prompt).content

    # avg calculate
    avg_score = sum(state['individual_scores'])/len(state['individual_scores'])

    return {'overall_feedback': overall_feedback, 'avg_score': avg_score}

# %%
# Graph 
graph = StateGraph(UPSCState)

# Nodes
graph.add_node("Language_Evaluation", language_evaluation)
graph.add_node("Analysis_Evaluation", analysis_evaluation)
graph.add_node("Clarity_Evaluation", clarity_evaluation)
graph.add_node("Final_Evaluation", final_evaluation)

# Edges
graph.add_edge(START, "Language_Evaluation")
graph.add_edge(START, "Analysis_Evaluation")
graph.add_edge(START, "Clarity_Evaluation")

graph.add_edge("Language_Evaluation", "Final_Evaluation")
graph.add_edge("Analysis_Evaluation", "Final_Evaluation")
graph.add_edge("Clarity_Evaluation", "Final_Evaluation")

graph.add_edge("Final_Evaluation", END)

# compile
workflow = graph.compile()

# %%
workflow

# %%
Essay2 = """India in the Age of AI
As the world enters a transformative era defined by artificial intelligence (AI), India stands at a critical juncture — one where it can either emerge as a global leader in AI innovation or risk falling behind in the technology race. The age of AI brings with it immense promise as well as unprecedented challenges, and how India navigates this landscape will shape its socio-economic and geopolitical future.

India's strengths in the AI domain are rooted in its vast pool of skilled engineers, a thriving IT industry, and a growing startup ecosystem. With over 5 million STEM graduates annually and a burgeoning base of AI researchers, India possesses the intellectual capital required to build cutting-edge AI systems. Institutions like IITs, IIITs, and IISc have begun fostering AI research, while private players such as TCS, Infosys, and Wipro are integrating AI into their global services. In 2020, the government launched the National AI Strategy (AI for All) with a focus on inclusive growth, aiming to leverage AI in healthcare, agriculture, education, and smart mobility.

One of the most promising applications of AI in India lies in agriculture, where predictive analytics can guide farmers on optimal sowing times, weather forecasts, and pest control. In healthcare, AI-powered diagnostics can help address India’s doctor-patient ratio crisis, particularly in rural areas. Educational platforms are increasingly using AI to personalize learning paths, while smart governance tools are helping improve public service delivery and fraud detection.

However, the path to AI-led growth is riddled with challenges. Chief among them is the digital divide. While metropolitan cities may embrace AI-driven solutions, rural India continues to struggle with basic internet access and digital literacy. The risk of job displacement due to automation also looms large, especially for low-skilled workers. Without effective skilling and re-skilling programs, AI could exacerbate existing socio-economic inequalities.

Another pressing concern is data privacy and ethics. As AI systems rely heavily on vast datasets, ensuring that personal data is used transparently and responsibly becomes vital. India is still shaping its data protection laws, and in the absence of a strong regulatory framework, AI systems may risk misuse or bias.

To harness AI responsibly, India must adopt a multi-stakeholder approach involving the government, academia, industry, and civil society. Policies should promote open datasets, encourage responsible innovation, and ensure ethical AI practices. There is also a need for international collaboration, particularly with countries leading in AI research, to gain strategic advantage and ensure interoperability in global systems.

India’s demographic dividend, when paired with responsible AI adoption, can unlock massive economic growth, improve governance, and uplift marginalized communities. But this vision will only materialize if AI is seen not merely as a tool for automation, but as an enabler of human-centered development.

In conclusion, India in the age of AI is a story in the making — one of opportunity, responsibility, and transformation. The decisions we make today will not just determine India’s AI trajectory, but also its future as an inclusive, equitable, and innovation-driven society."""

# %%
# Execuation
initial_state = {"essay": Essay2}

final_state = workflow.invoke(initial_state)

final_state
# Out:
# {'essay': "India in the Age of AI\nAs the world enters a transformative era defined by artificial intelligence (AI), India stands at a critical juncture — one where it can either emerge as a global leader in AI innovation or risk falling behind in the technology race. The age of AI brings with it immense promise as well as unprecedented challenges, and how India navigates this landscape will shape its socio-economic and geopolitical future.\n\nIndia's strengths in the AI domain are rooted in its vast pool of skilled engineers, a thriving IT industry, and a growing startup ecosystem. With over 5 million STEM graduates annually and a burgeoning base of AI researchers, India possesses the intellectual capital required to build cutting-edge AI systems. Institutions like IITs, IIITs, and IISc have begun fostering AI research, while private players such as TCS, Infosys, and Wipro are integrating AI into their global services. In 2020, the government launched the National AI Strategy (AI for All) with a focus on inclusive growth, aiming to leverage AI in healthcare, agriculture, education, and smart mobility.\n\nOne of the most promising applications of AI in India lies in agriculture, where predictive analytics can guide farmers on optimal sowing times, weather forecasts, and pest control. In healthcare, AI-powered diagnostics can help address India’s doctor-patient ratio crisis, particularly in rural areas. Educational platforms are increasingly using AI to personalize learning paths, while smart governance tools are helping improve public service delivery and fraud detection.\n\nHowever, the path to AI-led growth is riddled with challenges. Chief among them is the digital divide. While metropolitan cities may embrace AI-driven solutions, rural India continues to struggle with basic internet access and digital literacy. The risk of job displacement due to automation also looms large, especially for low-skilled workers. Without effective skilling and re-skilling programs, AI could exacerbate existing socio-economic inequalities.\n\nAnother pressing concern is data privacy and ethics. As AI systems rely heavily on vast datasets, ensuring that personal data is used transparently and responsibly becomes vital. India is still shaping its data protection laws, and in the absence of a strong regulatory framework, AI systems may risk misuse or bias.\n\nTo harness AI responsibly, India must adopt a multi-stakeholder approach involving the government, academia, industry, and civil society. Policies should promote open datasets, encourage responsible innovation, and ensure ethical AI practices. There is also a need for international collaboration, particularly with countries leading in AI research, to gain strategic advantage and ensure interoperability in global systems.\n\nIndia’s demographic dividend, when paired with responsible AI adoption, can unlock massive economic growth, improve governance, and uplift marginalized communities. But this vision will only materialize if AI is seen not merely as a tool for automation, but as an enabler of human-centered development.\n\nIn conclusion, India in the age of AI is a story in the making — one of opportunity, responsibility, and transformation. The decisions we make today will not just determine India’s AI trajectory, but also its future as an inclusive, equitable, and innovation-driven society.",
#  'language_feedback': 'The essay titled "India in the Age of AI" presents a comprehensive overview of India\'s position and potential in the landscape of artificial intelligence. The author adeptly balances the opportunities and challenges presented by AI while relying on a logical structure that enhances readability. Here’s a detailed evaluation based on various aspects:\n\n1. **Clarity and Coherence**: The essay is clear, with a logical flow from introduction to conclusion. Each paragraph transitions smoothly to the next, making it easy for readers to follow the author’s argument. Additionally, the use of outlines such as strengths, opportunities, challenges, and strategies provides a structured approach that enhances clarity.\n\n2. **Language and Style**: The language used is articulate, precise, and appropriate for the intended audience. The sentences are well-constructed, with careful word choice that expresses complex ideas in an accessible manner. Some phrases could be simplified for even broader accessibility, but overall, the academic tone suits the topic well.\n\n3. **Depth of Analysis**: The essay does a commendable job at analyzing different facets of AI in India. It references significant statistics and governance strategies (like the National AI Strategy), which supports its arguments with empirical data. The application of AI in various sectors is discussed meaningfully, showcasing the potential benefits.\n\n4. **Critical Thinking**: The author has effectively identified potential problems, such as digital divides and privacy issues, and acknowledges the risks involved with AI adoption. However, this section could include more detailed proposals or examples of successful models from other countries to strengthen the arguments further.\n\n5. **Conclusion**: The conclusion wraps up the main ideas while emphasizing the critical nature of decision-making regarding AI. It reiterates the potential for a transformative impact, leaving the reader with a sense of urgency and responsibility.\n\n**Suggestions for Improvement**:\n- Adding specific examples or case studies of successful AI applications in India would enhance the depth of the analysis.\n- More emphasis on the ethical challenges could enrich the discussion further, especially regarding regional disparities.\n- Including counterarguments or potential downsides of AI adoption would provide a more rounded perspective.\n\nOverall, the essay successfully highlights India\'s prospects and challenges in AI while engaging the reader with thoughtful insights and a well-organized narrative. \n\n**Score**: 8/10',
#  'analysis_feedback': "The essay presents a comprehensive analysis of India's position in the realm of artificial intelligence (AI). It effectively outlines both the strengths and challenges that India faces in leveraging AI for economic and social development. The introduction succinctly frames the importance of AI while presenting the stakes involved. The essay is structured well, with clear sections that discuss India's capabilities in AI, promising applications, encountered challenges, and necessary approaches for ethical development. \n\nStrengths:\n1. **Clear Structure:** The essay is logically organized, making it easy to follow the argument from strengths to challenges and solutions.\n2. **Relevant Examples:** The use of concrete examples, such as the applications of AI in agriculture and healthcare, effectively supports the claims made about India's potential.\n3. **Balanced Perspective:** The essay presents a balanced view by not only highlighting the opportunities but also addressing the significant challenges such as the digital divide and data privacy concerns.\n4. **Holistic Approach:** Emphasizing a multi-stakeholder approach for responsible AI development shows a nuanced understanding of the complexities involved in policy-making.\n\nAreas for Improvement:\n1. **Depth of Analysis:** While the essay covers many aspects, some sections could benefit from deeper elaboration, particularly on the specific implications of the digital divide and data privacy concerns. More statistics or case studies could strengthen the arguments.\n2. **Conclusion Enhancement:** The conclusion reiterates the main ideas but could be more impactful if it included a call to action or specific recommendations that India should prioritize moving forward.\n3. **Citations and References:** Including references to studies, reports, or expert opinions would lend credibility and depth to the analysis, and assist readers in further exploration of the topic.\n\nOverall, the essay does an excellent job of navigating the complex landscape of AI in India, but could be enhanced with more detailed insights and supporting data. It effectively invokes a sense of urgency and responsibility regarding AI's development in the country.",
#  'clarity_feedback': 'The essay provides a comprehensive overview of India’s position in the field of Artificial Intelligence (AI), highlighting both its strengths and challenges. The introduction effectively sets the stage for the importance of AI in India, while the body elaborates on specific applications and issues in a structured manner. The use of statistics, such as the number of STEM graduates, lends credibility to the claims made. However, the essay could benefit from a more profound analysis of how the proposed solutions can be implemented, as well as examples of successful initiatives already in place. Additionally, the conclusion, while summarizing key points, could have been stronger by offering a more compelling call to action or visionary statement about India’s future with AI. The writing is generally clear and concise, with a logical flow of ideas; however, some sentences are quite complex and could be simplified for better readability. Overall, the essay is well-researched and presents a balanced view of AI in India, though it could emphasize action-oriented strategies more clearly. \n\nHere are some specific areas of improvement:\n1. **Implementation Details**: Discuss specific existing programs or policies that address the challenges mentioned, particularly in digital literacy and skilling.\n2. **Simplification of Complex Ideas**: Some technical concepts could benefit from clearer explanations or simpler language.\n3. **Stronger Conclusion**: The essay could end with a more impactful statement that encapsulates the urgency and potential of AI in India.\n\nScore: 8/10',
#  'overall_feedback': '**Summarized Feedback for the Essay "India in the Age of AI"**\n\nThe essay offers a thorough examination of India\'s position in the artificial intelligence (AI) landscape, effectively balancing the opportunities and challenges associated with AI adoption. It is well-structured, allowing the reader to follow the progression of ideas clearly and logically. The language used is articulate and suitable for the intended audience, although some phrases could be simplified for broader accessibility.\n\n**Strengths:**\n1. **Clear Structure**: The essay is organized logically, with distinct sections for strengths, opportunities, challenges, and strategies.\n2. **Relevant Examples**: Concrete examples, particularly in the fields of agriculture and healthcare, help substantiate claims regarding India’s potential in AI.\n3. **Balanced Perspective**: The discussion includes both opportunities and significant challenges, such as the digital divide and data privacy concerns.\n4. **Holistic Approach**: Emphasizing a multi-stakeholder approach reflects a nuanced understanding of the complexities involved in AI policy-making.\n\n**Areas for Improvement:**\n1. **Depth of Analysis**: More detailed exploration of the implications of the digital divide and privacy concerns, along with additional statistics or case studies, would strengthen the analysis further.\n2. **Implementation Details**: Discussion of existing programs or policies addressing identified challenges would enhance practicality and relevance.\n3. **Stronger Conclusion**: The conclusion could be made more impactful by incorporating a clearer call to action or visionary statement about India\'s AI future.\n\n**Overall Impression**: The essay is well-researched and provides a balanced view of AI\'s potential and risks in India. However, incorporating more detailed insights, simplified language for complex ideas, and articulating action-oriented strategies could enhance its effectiveness.\n\n**Score**: 8/10',
#  'individual_scores': [8, 8, 8],
#  'avg_score': 8.0}
