# %% [markdown]
# #### Getting started With Langchain And Open AI
#
# In this quickstart we'll see how to:
#
# - Get setup with LangChain, LangSmith and LangServe
# - Use the most basic and common components of LangChain: prompt templates, models, and output parsers.
# - Build a simple application with LangChain
# - Trace your application with LangSmith
# - Serve your application with LangServe

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY')

# LangSmith Tracing
os.environ['LANGCHAIN_API_KEY'] = os.getenv('LANGCHAIN_API_KEY')
os.environ['LANGSMITH_TRACING'] = 'true'
os.environ['LANGCHAIN_PROJECT'] = os.getenv('LANGCHAIN_PROJECT')

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model='gpt-4o')
# print(llm)

# %%
# Input and get response
result = llm.invoke("What is Generative AI?")
print(result)
# Out:
# content='Generative AI refers to a category of artificial intelligence systems designed to generate content, such as text, images, music, or other media. Unlike traditional AI systems that might focus on analyzing data or making predictions, generative AI models create new data based on the patterns and information they have learned from existing data.\n\nSome notable techniques and models associated with generative AI include:\n\n1. **Generative Adversarial Networks (GANs):** These consist of two neural networks— a generator and a discriminator— that are trained together. The generator creates new data, while the discriminator evaluates it. Through this adversarial process, the generator improves its ability to produce realistic outputs.\n\n2. **Variational Autoencoders (VAEs):** VAEs are used for generating new data by learning a probabilistic model of the input data. They encode input data into a compressed format and then decode it, allowing for controlled generation of new, similar data.\n\n3. **Transformers:** These are highly versatile and powerful models that have been used for tasks like natural language processing. They form the basis of major language models, such as GPT (Generative Pre-trained Transformer) developed by OpenAI, which can generate coherent and contextually relevant text.\n\nGenerative AI can be applied across various fields, from creating realistic images and video content to composing music, designing virtual environments, and even assisting in drug discovery. It opens up possibilities for creativity and automation, while also raising discussions around ethical implications, such as deepfakes, intellectual property, and the responsible use of AI technology.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 313, 'prompt_tokens': 13, 'total_tokens': 326, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cbf1785567', 'id': 'chatcmpl-CBGAobjFypzBbobLEqfsJsoPnAEGj', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--440b1ef6-af64-4b5e-9681-3f7257f07b71-0' usage_metadata={'input_tokens': 13, 'output_tokens': 313, 'total_tokens': 326, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
# ChatPrompt template
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a helpful assistant."),
        ("human", "{input}"),
    ]
)

# %%
# Chain
chain = prompt | llm

result = chain.invoke({"input": "What is LangSmith Useful for?"})
print(result)
# Out:
# content='LangSmith is a platform designed to help developers and teams build, test, evaluate, and monitor applications that use large language models (LLMs) and generative AI. It is particularly useful for managing and optimizing the behavior of LLM-based applications in production settings. Key functionalities of LangSmith include:\n\n1. **Prototyping and Development:** LangSmith aids in rapidly prototyping applications that leverage language models, allowing developers to experiment with different configurations and components.\n\n2. **Testing:** The platform provides tools to test the performance and output of language models to ensure they meet desired criteria and handle edge cases effectively.\n\n3. **Evaluation:** Developers can use LangSmith to evaluate the quality and effectiveness of their language models, comparing outputs against benchmarks and user expectations.\n\n4. **Monitoring:** LangSmith offers monitoring capabilities to observe how language models perform in real-time or over prolonged periods, enabling developers to detect issues and optimize performance.\n\n5. **Debugging:** The platform helps in diagnosing and troubleshooting problems within language model applications, allowing developers to pinpoint issues and improve model responses.\n\n6. **Pipeline Management:** LangSmith can manage the entire lifecycle of model deployment, from development through to production, ensuring smooth transitions and operation.\n\nOverall, LangSmith is designed to streamline the process of working with language models, enhance reliability, and improve the overall development lifecycle of AI-driven applications.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 273, 'prompt_tokens': 24, 'total_tokens': 297, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_80956533cb', 'id': 'chatcmpl-CBGFa3liLXjmXUajxOo4WoXIelsbr', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--43bf1c24-4028-4c60-bb35-e500efaffee2-0' usage_metadata={'input_tokens': 24, 'output_tokens': 273, 'total_tokens': 297, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
type(result)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
# StrOutputParser
from langchain_core.output_parsers import StrOutputParser

parser = StrOutputParser()

chain = prompt | llm | parser

result = chain.invoke({"input": "What is LangChain Useful for?"})
print(result)
# Out:
# LangChain is a framework designed to facilitate the development of applications powered by large language models (LLMs). It's particularly useful in scenarios where language models are employed for tasks such as natural language processing, understanding, and generation. Here are some of the key use cases and areas where LangChain is beneficial:
#
# 1. **Conversational Agents:** LangChain can be used to build sophisticated chatbots and virtual assistants that can understand and generate human-like responses.
#
# 2. **Content Generation:** It can assist in automating content creation, such as writing articles, creating marketing copy, or generating product descriptions.
#
# 3. **Question Answering Systems:** LangChain enables the development of systems that can answer questions by drawing from a set of documents or datasets. By integrating with vector stores and embedding models, it can provide accurate and context-aware answers.
#
# 4. **Text Summarization:** LangChain can be used to summarize long documents into concise and relevant summaries, making it easier to digest large information sources.
#
# 5. **Enterprise Knowledge Management:** By integrating with knowledge bases and document retrieval systems, LangChain can provide enterprise solutions for managing and retrieving information.
#
# 6. **Natural Language Understanding:** LangChain helps in building systems that can extract relevant information from text, perform sentiment analysis, or understand the nuances and intent in user inputs.
#
# 7. **Customization and Scalability:** LangChain provides tools for chaining together various components, such as LLMs, APIs, and data retrieval systems, allowing developers to create tailored applications that are scalable and flexible.
#
# In summary, LangChain is useful for building intelligent applications that leverage the power of language models for a variety of tasks, enhancing both productivity and user interaction capabilities.
