# %%
corpus = """
Hello Welcome, to Hemant Sabale's NLP Tutorials.
Please do watch the entire course! to become expert in NLP.
"""

# %%
print(corpus)
# Out:
# Hello Welcome, to Hemant Sabale's NLP Tutorials.
# Please do watch the entire course! to become expert in NLP.

# %%
#  Tokenization
# Sentence --> paragraphs
    
from nltk.tokenize import sent_tokenize

# %%
documents = sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello Welcome, to Hemant Sabale's NLP Tutorials.
# Please do watch the entire course!
# to become expert in NLP.

# %%
# Tokenization
# Paragraph --> words
# sentence ---> words

from nltk.tokenize import word_tokenize

# %%
words = word_tokenize(corpus)

words
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Hemant',
#  'Sabale',
#  "'s",
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
for word in words:
    print(word)
# Out:
# Hello
# Welcome
# ,
# to
# Hemant
# Sabale
# 's
# NLP
# Tutorials
# .
# Please
# do
# watch
# the
# entire
# course
# !
# to
# become
# expert
# in
# NLP
# .

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Hemant',
#  'Sabale',
#  "'",
#  's',
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Hemant',
#  'Sabale',
#  "'s",
#  'NLP',
#  'Tutorials.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize

text = "I love learning Data Science. NLP is fun!"

# Sentence Tokenization
sent_tokens = sent_tokenize(text)
print("Sentence Tokens:", sent_tokens)

# Word Tokenization
word_tokens = word_tokenize(text)
print("Word Tokens:", word_tokens)
# Out:
# Sentence Tokens: ['I love learning Data Science.', 'NLP is fun!']
# Word Tokens: ['I', 'love', 'learning', 'Data', 'Science', '.', 'NLP', 'is', 'fun', '!']
