# %% [markdown]
# ## Stemming
# Stemming is the process of reducing a word to its word stem that affixes to suffixes and prefixes or to the roots of words known as a lemma. Stemming is important in natural language understanding (NLU) and natural language processing (NLP).

# %%
## Classification Problem
## Comments of product is a positive review or negative review
## Reviews----> eating, eat, eaten [going, gone, goes] --> go

words = ["eating", "eats", "eaten", "going", "goes", "gone", "writing", "writes", "programming", "programs", "history", "finally", "finalized"]

# %% [markdown]
# ### PorterStemmer

# %%
from nltk.stem import PorterStemmer

# %%
stemming = PorterStemmer()

# %%
for word in words:
    print(word + " ==> " + stemming.stem(word))
# Out:
# eating ==> eat
# eats ==> eat
# eaten ==> eaten
# going ==> go
# goes ==> goe
# gone ==> gone
# writing ==> write
# writes ==> write
# programming ==> program
# programs ==> program
# history ==> histori
# finally ==> final
# finalized ==> final

# %%
stemming.stem('congratulations')
# Out:
# 'congratul'

# %%
stemming.stem("sitting")
# Out:
# 'sit'

# %% [markdown]
# ### RegexpStemmer class
# NLTK has RegexpStemmer class with the help of which we can easily implement Regular Expression Stemmer algorithms. It basically takes a single regular expression and removes any prefix or suffix that matches the expression. Let us see an example

# %%
from nltk.stem import RegexpStemmer

# %%
reg_stemmer = RegexpStemmer('ing$|s$|e$|able$', min=4)

# %%
reg_stemmer.stem('eating')
# Out:
# 'eat'

# %%
reg_stemmer.stem('ingeating')
# Out:
# 'ingeat'

# %% [markdown]
# ### Snowball Stemmer
#  It is a stemming algorithm which is also known as the Porter2 stemming algorithm as it is a better version of the Porter Stemmer since some issues of it were fixed in this stemmer.

# %%
from nltk.stem import SnowballStemmer

# %%
snowballsstemmer = SnowballStemmer('english')

# %%
for word in words:
    print(word + " ==> " + snowballsstemmer.stem(word))
# Out:
# eating ==> eat
# eats ==> eat
# eaten ==> eaten
# going ==> go
# goes ==> goe
# gone ==> gone
# writing ==> write
# writes ==> write
# programming ==> program
# programs ==> program
# history ==> histori
# finally ==> final
# finalized ==> final

# %%
stemming.stem("fairly"), stemming.stem("sportingly")
# Out:
# ('fairli', 'sportingli')

# %%
snowballsstemmer.stem("fairly"), snowballsstemmer.stem("sportingly")
# Out:
# ('fair', 'sport')

# %%
snowballsstemmer.stem('goes')
# Out:
# 'goe'

# %%
stemming.stem('goes')
# Out:
# 'goe'

# %%
reg_stemmer.stem('goes')
# Out:
# 'goe'

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

ps = PorterStemmer()

text = "I am loving the way he studies and plays football every day"
tokens = word_tokenize(text)

print("Original Tokens:", tokens)
print("\nAfter Stemming:")

for word in tokens:
    print(word, "→", ps.stem(word))
# Out:
# Original Tokens: ['I', 'am', 'loving', 'the', 'way', 'he', 'studies', 'and', 'plays', 'football', 'every', 'day']
#
# After Stemming:
# I → i
# am → am
# loving → love
# the → the
# way → way
# he → he
# studies → studi
# and → and
# plays → play
# football → footbal
# every → everi
# day → day

# %%
from nltk.stem import PorterStemmer, LancasterStemmer, SnowballStemmer

porter = PorterStemmer()
lancaster = LancasterStemmer()
snowball = SnowballStemmer("english")

words =  ['I', 'am', 'loving', 'the', 'way', 'he', 'studies', 'and', 'plays', 'football', 'every', 'day']

print("PorterStemmer:", [porter.stem(word) for word in words])
print("LancasterStemmer:", [lancaster.stem(word) for word in words])
print("SnowballStemmer:", [snowball.stem(word) for word in words])
# Out:
# PorterStemmer: ['i', 'am', 'love', 'the', 'way', 'he', 'studi', 'and', 'play', 'footbal', 'everi', 'day']
# LancasterStemmer: ['i', 'am', 'lov', 'the', 'way', 'he', 'study', 'and', 'play', 'footbal', 'every', 'day']
# SnowballStemmer: ['i', 'am', 'love', 'the', 'way', 'he', 'studi', 'and', 'play', 'footbal', 'everi', 'day']

# %%
word = "studies"

print("PorterStemmer:", porter.stem(word))
print("LancasterStemmer:", lancaster.stem(word))
print("SnowballStemmer:", snowball.stem(word))
# Out:
# PorterStemmer: studi
# LancasterStemmer: study
# SnowballStemmer: studi
